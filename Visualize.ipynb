# %%
import pandas as pd

# %%
df = pd.read_csv('googleplaystore.csv')

# %%
df_ur = pd.read_csv('googleplaystore_user_reviews.csv')

# %%
pd.plotting.scatter_matrix(df)
# Out:
# array([[<AxesSubplot:xlabel='Rating', ylabel='Rating'>]], dtype=object)

# %%
pd.plotting.scatter_matrix(df_ur)
# Out:
# array([[<AxesSubplot:xlabel='Sentiment_Polarity', ylabel='Sentiment_Polarity'>,
#         <AxesSubplot:xlabel='Sentiment_Subjectivity', ylabel='Sentiment_Polarity'>],
#        [<AxesSubplot:xlabel='Sentiment_Polarity', ylabel='Sentiment_Subjectivity'>,
#         <AxesSubplot:xlabel='Sentiment_Subjectivity', ylabel='Sentiment_Subjectivity'>]],
#       dtype=object)
